# %%
# %matplotlib inline
import numpy as np
import pylab as plt
filename='/Users/noahknoblauch/Documents/PulseLab.txt'
data=np.loadtxt(filename)

meter=data[:,0]
amplitude=data[:,1]

plt.plot(meter,amplitude)
plt.ylim(0,100)
plt.xlabel('Meter')
plt.ylabel('Amplitude Percentage')
